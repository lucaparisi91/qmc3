# %%
import numpy as np
import matplotlib.pylab as plt
import scipy as sp
import pandas as pd
import plotly.express as px
from scipy.special import erfc
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from numpy.linalg import norm
from math import *
from scipy.special import log_ndtr
erfc=np.vectorize(erfc)

# %%
#Green functions

# %%
## Contact interactions

# %%
def erfc_expx2(x):
    return erfc(x)*np.exp(x**2)

# %%
def F(r,rp,a,beta):
    arg=np.sqrt(1/beta)*(r+rp)*0.5 - np.sqrt(beta)/a
    print(arg)
    return 1 + 1/a*np.sqrt(pi*beta)*erfc_expx2(arg)
    

def g(x,xprime,beta,a):
    r=norm(x)
    rp=norm(xprime)
    return F(r,rp,a,beta)
    #return 1 + 2*beta/(r*rp)*np.exp(-(r*rp + np.dot(x,xprime)/(2*beta) ) )*F(r,rp,a,beta)

# %%
# %matplotlib notebook
beta=1
a=0.1
rs=np.linspace(1,30,num=100)
xs=[ np.array([0,0,1])]
ys=[ np.array([0,0,r]) for r in  rs ]
gs = [ g(x,y,beta,a) for x in xs for y in ys  ]
plt.plot(rs,gs,"o--")
# Out:
# -9.0
# -8.853535353535353
# -8.707070707070708
# -8.56060606060606
# -8.414141414141413
# -8.267676767676768
# -8.121212121212121
# -7.974747474747475
# -7.828282828282829
# -7.681818181818182
# -7.5353535353535355
# -7.388888888888889
# -7.242424242424242
# -7.095959595959596
# -6.94949494949495
# -6.803030303030303
# -6.656565656565657
# -6.51010101010101
# -6.363636363636363
# -6.217171717171717
# -6.070707070707071
# -5.924242424242424
# -5.777777777777778
# -5.6313131313131315
# -5.484848484848484
# -5.338383838383838
# -5.191919191919192
# -5.045454545454545
# -4.898989898989899
# -4.752525252525253
# -4.606060606060606
# -4.459595959595959
# -4.313131313131313
# -4.166666666666667
# -4.02020202020202
# -3.8737373737373737
# -3.7272727272727275
# -3.5808080808080804
# -3.4343434343434343
# -3.287878787878788
# -3.141414141414142
# -2.994949494949495
# -2.8484848484848486
# -2.7020202020202024
# -2.5555555555555554
# -2.409090909090909
# -2.262626262626263
# -2.116161616161616
# -1.9696969696969688
# -1.8232323232323235
# -1.6767676767676765
# -1.5303030303030312
# -1.383838383838384
# -1.237373737373737
# -1.09090909090909
# -0.9444444444444446
# -0.7979797979797976
# -0.6515151515151523
# -0.5050505050505052
# -0.3585858585858581
# -0.21212121212121282
# -0.06565656565656575
# 0.08080808080808133
# 0.22727272727272663
# 0.3737373737373737
# 0.5202020202020208
# 0.6666666666666661
# 0.8131313131313131
# 0.9595959595959602
# 1.1060606060606055
# 1.2525252525252526
# 1.3989898989898997
# 1.545454545454545
# 1.691919191919192
# 1.8383838383838391
# 1.9848484848484844
# 2.1313131313131315
# 2.2777777777777786
# 2.424242424242424
# 2.570707070707071
# 2.7171717171717162
# 2.8636363636363633
# 3.0101010101010104
# 3.1565656565656557
# 3.3030303030303028
# 3.44949494949495
# 3.595959595959595
# 3.742424242424242
# 3.8888888888888893
# 4.035353535353535
# 4.181818181818182
# 4.328282828282829
# 4.474747474747474
# 4.621212121212121
# 4.767676767676768
# 4.9141414141414135
# 5.0606060606060606
# 5.207070707070708
# 5.353535353535353
# 5.5
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
x=np.linspace(-1,-0.1,num=100)
def erfc_log(x):
    return np.log(2*(1-np.exp(log_ndtr(x*np.sqrt(2)))))
    
#plt.plot(x,erfc(x) ,label="erfc")

def erfc_expx2(x):
        A=1.98
        B=1.135
        if x==0:
            return 1.
        if (x>0):
            return (1-np.exp(-A*x1))/(B*np.sqrt(pi)*x1)
        else:
            return 2 - erfc_expx2(-x)
    
#plt.plot(x,erfc(x)*np.exp(x**2),label="direct")
plt.plot(x,np.vectorize(erfc_expx2)(x),label="indirect")
plt.plot(x,erfc(x)*np.exp(x**2),label="direct")
#plt.plot(x,2-erfc(-x),label="indirect")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-887be717c5c1> in <module>
#      17
#      18 #plt.plot(x,erfc(x)*np.exp(x**2),label="direct")
# ---> 19 plt.plot(x,erfc_expx2(x),label="indirect")
#      20 plt.plot(x,erfc(x)*np.exp(x**2),label="direct")
#      21 #plt.plot(x,2-erfc(-x),label="indirect")
#
# <ipython-input-48-887be717c5c1> in erfc_expx2(x)
#       9         A=1.98
#      10         B=1.135
# ---> 11         if x==0:
#      12             return 1.
#      13         if (x>0):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
